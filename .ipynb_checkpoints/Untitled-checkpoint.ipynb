# %%
import pandas as pd

# %%
Total_train = pd.read_csv('./Total_Train.csv')

# %%
Total_train
# Out:
#                                          answer_content answer_id  \
# 0     nasal septal perf if you already have an issue...    221733
# 1     perforated septum a perforated septum can occu...   2072359
# 2     may if you have a dry nose it may help to mois...    289757
# 3     possible while it is know that marijuana cause...   1432213
# 4     no reason 2 think so im sorry about your losse...   1432217
# 5     cannabis use by mother studies through vanderb...   1472141
# 6     adenoids  snoring hello  when we prescribe int...   1442458
# 7     temporary effects the nasal steroid only works...   1442427
# 8     can choose first  if he is snoring but otherwi...   1453856
# 9     its possible sexsteroid binding globulins affe...   1469188
# 10    yes if a man can ejaculate  he most certainly ...   1444135
# 11    probably shbg is not directly involved in fert...   1469399
# 12    hsv2 herpes simplex virus2 hsv2 is a virus tha...   1444630
# ...

# %%
Total_train.drop_duplicates('answer_id')
Total_train.drop_duplicates('answer_content')
# Out:
#                                          answer_content answer_id  \
# 0     nasal septal perf if you already have an issue...    221733
# 1     perforated septum a perforated septum can occu...   2072359
# 2     may if you have a dry nose it may help to mois...    289757
# 3     possible while it is know that marijuana cause...   1432213
# 4     no reason 2 think so im sorry about your losse...   1432217
# 5     cannabis use by mother studies through vanderb...   1472141
# 6     adenoids  snoring hello  when we prescribe int...   1442458
# 7     temporary effects the nasal steroid only works...   1442427
# 8     can choose first  if he is snoring but otherwi...   1453856
# 9     its possible sexsteroid binding globulins affe...   1469188
# 10    yes if a man can ejaculate  he most certainly ...   1444135
# 11    probably shbg is not directly involved in fert...   1469399
# 12    hsv2 herpes simplex virus2 hsv2 is a virus tha...   1444630
# ...

# %%
aid = Total_train[['answer_id']]

# %%
aid
# Out:
#       answer_id
# 0        221733
# 1       2072359
# 2        289757
# 3       1432213
# 4       1432217
# 5       1472141
# 6       1442458
# 7       1442427
# 8       1453856
# 9       1469188
# 10      1444135
# 11      1469399
# 12      1444630
# 13      1444619
# 14      1444596
# 15      1445743
# 16      1446136
# 17      1446092
# 18      1513753
# 19      1443742
# 20      2358242
# 21      1511833
# 22      1445589
# 23      1449044
# 24      1447835
# 25      1513700
# 26      1538241
# 27      1455773
# 28      1455786
# 29      1575901
# ...         ...
# 11597   1408152
# 11598   1408134
# 11599   1411843
# 11600   1411898
# 11601   1411855
# 11602   1412673
# 11603   1412677
# 11604   1470997
# 11605   1414546
# 11606   1415409
# 11607   1415723
# 11608   1416095
# 11609   1417102
# 11610   1416302
# 11611   1416648
# 11612   1418506
# 11613   1417378
# 11614   1417373
# 11615   1525489
# 11616    733920
# 11617    900670
# 11618    162052
# 11619   1424487
# ...

# %%
aid.drop_duplicates()
# Out:
#       answer_id
# 0        221733
# 1       2072359
# 2        289757
# 3       1432213
# 4       1432217
# 5       1472141
# 6       1442458
# 7       1442427
# 8       1453856
# 9       1469188
# 10      1444135
# 11      1469399
# 12      1444630
# 13      1444619
# 14      1444596
# 15      1445743
# 16      1446136
# 17      1446092
# 18      1513753
# 19      1443742
# 20      2358242
# 21      1511833
# 22      1445589
# 23      1449044
# 24      1447835
# 25      1513700
# 26      1538241
# 27      1455773
# 28      1455786
# 29      1575901
# ...         ...
# 11590   1555752
# 11591   1405089
# 11592   1401396
# 11593    202039
# 11594    160837
# 11595    160844
# 11596   1408155
# 11597   1408152
# 11598   1408134
# 11602   1412673
# 11603   1412677
# 11604   1470997
# 11609   1417102
# 11610   1416302
# 11611   1416648
# 11612   1418506
# 11613   1417378
# 11614   1417373
# 11615   1525489
# 11616    733920
# 11617    900670
# 11618    162052
# 11619   1424487
# ...

# %%
at = Total_train[['answer_content']]

# %%
at
# Out:
#                                           answer_content
# 0      nasal septal perf if you already have an issue...
# 1      perforated septum a perforated septum can occu...
# 2      may if you have a dry nose it may help to mois...
# 3      possible while it is know that marijuana cause...
# 4      no reason 2 think so im sorry about your losse...
# 5      cannabis use by mother studies through vanderb...
# 6      adenoids  snoring hello  when we prescribe int...
# 7      temporary effects the nasal steroid only works...
# 8      can choose first  if he is snoring but otherwi...
# 9      its possible sexsteroid binding globulins affe...
# 10     yes if a man can ejaculate  he most certainly ...
# 11     probably shbg is not directly involved in fert...
# 12     hsv2 herpes simplex virus2 hsv2 is a virus tha...
# 13     herpes here are some facts: 90% of those infec...
# 14     difficult to say certainly you could infect so...
# ...

# %%
at.drop_duplicates()
# Out:
#                                           answer_content
# 0      nasal septal perf if you already have an issue...
# 1      perforated septum a perforated septum can occu...
# 2      may if you have a dry nose it may help to mois...
# 3      possible while it is know that marijuana cause...
# 4      no reason 2 think so im sorry about your losse...
# 5      cannabis use by mother studies through vanderb...
# 6      adenoids  snoring hello  when we prescribe int...
# 7      temporary effects the nasal steroid only works...
# 8      can choose first  if he is snoring but otherwi...
# 9      its possible sexsteroid binding globulins affe...
# 10     yes if a man can ejaculate  he most certainly ...
# 11     probably shbg is not directly involved in fert...
# 12     hsv2 herpes simplex virus2 hsv2 is a virus tha...
# 13     herpes here are some facts: 90% of those infec...
# 14     difficult to say certainly you could infect so...
# ...
